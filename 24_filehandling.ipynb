# %%
file = open("demo.txt", "r")

# %%
print(file.read())
# Out:
# This is a test.
# New Line added!

# %%
file.close()

# %%
file = open("demo.txt", "w")

# %%
file.write("This is another test.")
# Out:
# 21

# %%
file.close()
