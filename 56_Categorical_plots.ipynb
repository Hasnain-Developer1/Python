# %%
# Load the Healthcare Daset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("healthcare_patient_analytics_seaborn.csv")

# %%
df = df.sample(500)
# barplot vs countplot
# countplot:
sns.countplot(
    data = df,
    x = "treatment_type"
)

plt.title("Number of Visits by Treatment-Type")
plt.show()

# %%
# barplot vs countplot
# - barplot
sns.barplot(
    data = df,
    x = "department",
    y = "treatment_cost"
)
plt.xticks(rotation = 30)
plt.title("Average Treatment Cost by department")
plt.show()

# %%
# Distribution bases - Categorical plots
# Boxplot - shows median, quartiles and outlier
sns.boxplot(
    data = df,
    x = "department",
    y = "recovery_score"
)
plt.xticks(rotation = 30)
plt.show()

# %%
# Distribution bases - Categorical plots
# Violinplot - Shows full Distribution shape

sns.violinplot(
    data = df,
    x = "department",
    y = "recovery_score"
)
plt.xticks(rotation = 30)
plt.show()

# %%
# Distribution bases - Categorical plots
# Swarm / Strip plot- Shows individuals data points
sns.stripplot(
    data = df,
    x = "department",
    y = "recovery_score",
    jitter = True
)
plt.xticks(rotation = 30)
plt.show()

# %%
# Side by Side comparison (Box + Strip)

sns.boxplot(
    data = df,
    x = "department",
    y = "recovery_score"
)

sns.stripplot(
    data = df,
    x = "department",
    y = "recovery_score",
    color = "black",
    alpha = 0.4
)
plt.xticks(rotation = 30)
plt.show()
