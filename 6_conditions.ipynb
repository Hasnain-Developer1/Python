# %%
temp = int(input("Enter the temprature:"))
# Out:
# Enter the temprature: 25

# %%
type(temp)
# Out:
# int

# %%
if temp > 35:
    print("It is hot weather")
else:
    print("It is not Hot weather")
# Out:
# It is not Hot weather

# %%
score = 70

# %%
if score >=90:
    print("A+")
elif score >=80: #elif  else if
    print("A")
else:
    print("Try again")
# Out:
# Try again

# %%
age = int(input("What is your age"))
if age >= 18:
    country = input("What is your country")
    if country == "Pakistan":  #nested if
        print("You can vote in Pakistan")
    else:
        print("you cannot vote in Pakistan")
else:
    print("You cannot vote ")
# Out:
# What is your age 21
# What is your country Pakistan
# You can vote in Pakistan

# %%
age = int(input("What is your age"))
country = input("What is your country").capitalize() # this function capitalize the first letter of the input string
if age >= 18 and country == "Pakistan":
    print("Eligible voter")
else:
    print("Not eligible voter")
# Out:
# What is your age 23
# What is your country pakistan
# Eligible voter

# %%
marks = 70
if marks >= 90:
    print("A+")
elif marks >= 80:
    print("A")
elif marks >= 70:
    print("B")
else:
    print("F")
# Out:
# B
