# %%
class Animal:
    def speak(self):
        print("some sound")

# %%
class Dog(Animal):
    def speak(self): #this method will be called, Not the method of parent class who has same method 
        print("Woof Woof")

# %%
Dog1 = Dog()

# %%
Dog1.speak()
# Out:
# Woof Woof
