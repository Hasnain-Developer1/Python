# %%
age = "35"

# %%
print(age)
# Out:
# 35

# %%
type(age)
# Out:
# str

# %%
print(int(age) + 1) #age was string now is added with integer
# Out:
# 36

# %% [markdown]
# # Input in Python

# %%
age = input("Write your age")
# Out:
# Write your age 20

# %%
print(age)
# Out:
# 20

# %%
type(age) # Input Data from user will be in string
# Out:
# str

# %%
myAge = int(age) # age will store as an integer in myAge

# %%
type(myAge)
# Out:
# int
