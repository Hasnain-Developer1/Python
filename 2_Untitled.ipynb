# %%
age = 25

# %%
print(age)
# Out:
# 25

# %%
score = 3.5

# %%
print(score)
# Out:
# 3.5

# %%
type(score)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
print(score+1)
# Out:
# 4.5

# %%
name = "Hasnain Malik"

# %%
print(name)
# Out:
# Hasnain Malik

# %%
print(name + " is learning AI")
# Out:
# Hasnain Malik is learning AI

# %%
is_passed = True

# %%
print(is_passed)
# Out:
# True
