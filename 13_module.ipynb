# %% [markdown]
# # Module

# %% [markdown]
# ### A module is a file containing large python code (functions, variables) we can import and reuse them

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt # only imported the required function from module math
print(sqrt(25))
# Out:
# 5.0

# %%
import mymodule
mymodule.greet()
# Out:
# Hello I am the module File
