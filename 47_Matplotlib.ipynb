# %% [markdown]
# # Matplotlib

# %% [markdown]
# #### Matplotlib provides a figure that act like a canvas on which various graphs & plots can be created

# %% [markdown]
# # Axes

# %% [markdown]
# #### The individula plot ares that contains the x-axis & y-axis

# %% [markdown]
# # 3D Ploting

# %% [markdown]
# ### Represent data usinh three axis: x-axis, y-axis & z-axis

# %%
import matplotlib.pyplot as plt

# Object Oriented Workflow
fig, ax = plt.subplots()

# Label axes
ax.set_title("Blank Figure Example")
ax.set_xlabel("x-axis label")
ax.set_ylabel("y-axis Label")

# save to PNG
fig.savefig("blank_plot.png", dpi=100)

plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
