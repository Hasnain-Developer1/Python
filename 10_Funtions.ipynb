# %% [markdown]
# # Functions in Python

# %%
def greet():
    print("Hello World")
greet()
# Out:
# Hello World

# %%
def greet(name):
    print("Hello", name)
greet("Ali")
# Out:
# Hello Ali

# %%
greet("Sara")
# Out:
# Hello Sara

# %%
def add(a, b):
    return a+ b

# %%
result = add(3, 5)
print(result)
# Out:
# 8

# %%
 def square(num):
     return num*num

# %%
result = square(5)
print(result)
# Out:
# 25
