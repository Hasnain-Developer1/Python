# %%
import pandas as pd

# %%
# Sample DataFrames
customers = pd.DataFrame({
    'Customer_id': [1,2,3];
    'name': ['Alices', 'Bob', 'Chatrles']
})

orders = pd.DataFrame({
    'OrderID': [101, 102, 103, 104],
    'CustomerID': [1,2,2,3],
    'amount': [250, 150, 200, 300]
})

# %%
# inner Merge on CustomerID
df_inner = pd.merge(customers, orders, on='CustomerID', how='inner')
print("Inner Merge\n", df_inner)

# %%
# Left Merge
df_left = pd.merge(customer, orders, on='CustomerID', how='left')
print("\n Left Merge:\n", df_left)

# %%
# concatenate row Example
df_concat = pd.concat([customer, customers])
print("\n concatenated Rows:\n", df_concat)
