# %%
def show():
    x = 5 # local Variable
    print(x)

# %%
x = 10 # Global variable
show() #loacal variable will be prefered over global variable it will print 5 not 10
# Out:
# 5

# %%
print(x)
# Out:
# 10

# %%
show()
# Out:
# 5
