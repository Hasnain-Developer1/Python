# %%
print(5 + 3) # Addition
print(8 - 5) # subtraction
# Out:
# 8
# 3

# %%
print(2 * 6) # Multiply
print( 17 / 3) # Divide
print( 17 // 3) # Floor Divide (Exact answer not decimal)
# Out:
# 12
# 5.666666666666667
# 5

# %%
print(10 % 3) # Reminder
print(2 ** 3) #Exponent (Power)
# Out:
# 1
# 8

# %%
print(5 == 5) #Equality
print(7 != 3) #InEqulity
print(10 > 2) #Greater then
print(4 < 1) # Less then
# Out:
# True
# True
# True
# False

# %%
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False

# %%
x = 10 #Simple asssignment
print(x)
x += 5 #same as x = x+5
print(x)
x -= 3 #Same as x = x-3
print(x)
x *= 2 #same as x = x*2
print(x)
x /= 4 #Same as x = x/4
print(x)
# Out:
# 10
# 15
# 12
# 24
# 6.0
